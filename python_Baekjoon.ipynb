# %% [markdown]
# <a href="https://colab.research.google.com/github/gwj0421/Gunwoong/blob/master/python_Baekjoon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
number=int(input())
for i in range(number):
    count=0
    num=input().split()
    scores=list(map(float,num[1:]))
    average=sum(scores)/len(scores)
    for temp in scores:
        if temp>average:
            count+=1
    print('{:.3f}%'.format(count/len(scores)*100))
